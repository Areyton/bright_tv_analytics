-- %%
-- to get an overview of how the data is recorded in the table
SELECT * 
FROM `brightlearn`.`bright_tv`.`viewership` 
LIMIT 100;

-- to how many users are there in the table
SELECT COUNT(UserID0) 
FROM `brightlearn`.`bright_tv`.`viewership`;

SELECT COUNT(DISTINCT UserID0) 
FROM `brightlearn`.`bright_tv`.`viewership`;

-- to get the number of channels in the table
